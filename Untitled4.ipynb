# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (e:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\python\lib\site-packages)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data_train_path = '/content/data2/train'
data_test_path = '/content/data2/test'
data_val_path = '/content/data2/val'

# %%
img_width = 180
img_height =180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 3231 files belonging to 90 classes.

# %%
data_cat = data_train.class_names

# %%
data_cat
# Out:
# ['antelope',
#  'badger',
#  'bat',
#  'bear',
#  'bee',
#  'beetle',
#  'bison',
#  'boar',
#  'butterfly',
#  'cat',
#  'caterpillar',
#  'chimpanzee',
#  'cockroach',
#  'cow',
#  'coyote',
#  'crab',
#  'crow',
#  'deer',
#  'dog',
#  'dolphin',
#  'donkey',
#  'dragonfly',
#  'duck',
#  'eagle',
#  'elephant',
#  'flamingo',
#  'fly',
#  'fox',
#  'goat',
#  'goldfish',
#  'goose',
#  'gorilla',
#  'grasshopper',
#  'hamster',
#  'hare',
#  'hedgehog',
#  'hippopotamus',
#  'hornbill',
#  'horse',
#  'hummingbird',
#  'hyena',
#  'jellyfish',
#  'kangaroo',
#  'koala',
#  'ladybugs',
#  'leopard',
#  'lion',
#  'lizard',
#  'lobster',
#  'mosquito',
#  'moth',
#  'mouse',
#  'octopus',
#  'okapi',
#  'orangutan',
#  'otter',
#  'owl',
#  'ox',
#  'oyster',
#  'panda',
#  'parrot',
#  'pelecaniformes',
#  'penguin',
#  'pig',
#  'pigeon',
#  'porcupine',
#  'possum',
#  'raccoon',
#  'rat',
#  'reindeer',
#  'rhinoceros',
#  'sandpiper',
#  'seahorse',
#  'seal',
#  'shark',
# ...

# %%
data_val = tf.keras.utils.image_dataset_from_directory(data_val_path,
                                                       image_size=(img_height,img_width),
                                                       batch_size=32,
                                                        shuffle=False,
                                                       validation_split=False)
# Out:
# Found 402 files belonging to 90 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
data_test_path,
    image_size=(img_height,img_width),
    shuffle=False,
    batch_size=32,
    validation_split=False
)
# Out:
# Found 419 files belonging to 90 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))

])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 25
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/25
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.0404 - loss: 4.3179 - val_accuracy: 0.1318 - val_loss: 3.6322
# Epoch 2/25
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.2226 - loss: 3.2347 - val_accuracy: 0.2164 - val_loss: 3.3311
# Epoch 3/25
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.5065 - loss: 2.0126 - val_accuracy: 0.3209 - val_loss: 3.1248
# Epoch 4/25
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.7572 - loss: 0.8891 - val_accuracy: 0.3706 - val_loss: 3.8835
# Epoch 5/25
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.9193 - loss: 0.3416 - val_accuracy: 0.3532 - val_loss: 4.6209
# Epoch 6/25
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9508 - loss: 0.2060 - val_accuracy: 0.3607 - val_loss: 5.0735
# Epoch 7/25
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9730 - loss: 0.1153 - val_accuracy: 0.3905 - val_loss: 4.9954
# Epoch 8/25
# ...

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = '/content/data2/train/antelope/02f4b3be2d.jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('bird/Animal in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# bird/Animal in image is antelope with accuracy of 100.00

# %%
model.save('Image_classify.keras')
